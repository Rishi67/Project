# %% [markdown]
# # Deep vs Shallow Neural Networks

# %% [markdown]
# Here we want to study is the trade off between the depth of a neural network and the size of the hidden layers.
#
# ## 1 Architecture
#
# Concretely we will be looking at two different neural networks for classificstion of the same data. Hence let us look at the architeture of the two networks we will be considering
#
# ### 1.1 Deep Architecture
#
# For the deep arichtecture we shall consider a neural netowkrm with 2 hidden layers. Here each of the two hidden layers will have $m$ nodes. Thus let $W_1,W_2,W_3$ be $m \times 2$, $m \times m$, and $m \times 1$ matrices and let $b_1$ and $b_2$ be two $m \times 1$ vectors and $b_3$ is a 1 dimensional vector. Then we have that our architecture is
#
# $$y = W_3 f(W_2f(W_1x + b_1)+b_2) + b_3$$
#
# where $x$ is the input point, $y$ is label and $f(x) = ReLu(x) = \max(0,x)$ is the non linear activstion function.

# %% [markdown]
# ### 1.2 Shallow Architecture
#
# For the shallow aritecture we will only have 1 hidden layer with $n$ nodes. Here let $W_1,W_2$ be $n \times 2$ and $n \times 1$ matrices and let $b_1$ be a vector of length $n$ and $b_2$ a 1 dimensional vector. Then we have that
#
# $$y = W_2f(W_1x + b_1)+b_2 $$
#
# where $x$ is the input point, $y$ is label and $f(x) = ReLu(x) = \max(0,x)$ is the non linear activstion function.

# %% [markdown]
# ### 1.3 Optimization Method
#
# Here we learn the weights using Stochastic Gradient Descent, using the Nesterov Momentum algorithm with gradient clip = 0 and $\gamma = 0.9$.
#
# We will also experiment with the learning rate and number of epoachs. But a lot of the results can be seen with $\mu = 1e-4$ and $\texttt{epochs}=10000$.
#
# Here we also used a batch sise of 10 with a training data set of size 2000 (1000 of each label) and a testing set of size 2000 (1000 each label).

# %% [markdown]
# ## 2 Data
#
# The two labels that we want to lesrn are given by two interlocking archimedean spirals. Where $$ c_1 = (\theta \cos(\theta) + \epsilon_1, \theta\sin(\theta)+ \epsilon_2) \text{ and } c_2 = -(\theta \cos(\theta)+ \epsilon_3, \theta\sin(\theta)+ \epsilon_4)$$
#
# Where $\epsilon_i$ is some standard gaussian noise
#
# The following piece of code will let us visualize this data for various number of data points.

# %%
using Interact, Plots
gr()
# Out:
# Plots.GRBackend()

# %%
function generate_data(a,r,n)
    theta = 4*pi*rand(n,)
    x = zeros(n,2)
    for i = 1:n
        x[i,1] = a*(theta[i]^(1/r))*sin(theta[i])
        x[i,2] = a*(theta[i]^(1/r))*cos(theta[i])
    end
    
    return x
end

function input(prompt::String="")::String
    print(prompt)
    return chomp(readline())
end

@manipulate for n = parse(Int, input())
    x1 = generate_data(1,1,n) + randn(n,2)/2
    x2 = generate_data(-1,1,n) + randn(n,2)/2

    scatter(x1[:,[2]],x1[:,[1]])
    scatter!(x2[:,[2]],x2[:,[1]])
end

# %% [markdown]
# ### 2.1 Data encoding and loss function
#
# Here we will consider the blue points to have a label of 1 and the red points in the above picture to have a of 0. Here we will mean squared error as the loss fucntion

# %% [markdown]
# ##  3 Results and conjectures
#
# From the data that we generated we csn hypothesize the following relaion. If we had $m$ nodes in esach hidden layer of the deep architecture, then to achieve the same average error (i.e (MSE training + MSE test)/2) then we need $n = \frac{3}{2}m^2$ in the shallow network.
#
# The following piece of code shows the plot which suggests this

# %%
using JLD

n = 1:150
m = 1:17
f3(x) = 1.5x^2
m3 = f3.(m)

deep_err = load("deep_err.jld")["deep_err"]
shallow_err = load("shallow_err.jld")["shallow_err"]

scatter(m3,deep_err, label = "Deep MSE")
scatter!(n,shallow_err, xlabel = "n or 1.5m²", ylabel = "Average MSE", label = "Shallow MSE")

# %% [markdown]
# $\textbf{TODO: Run shallow for n from 150 to 300 to see if it fits the data. (This would take about a day if I ran it for all 150 values of n)}$

# %% [markdown]
# ## Examples
#
# Let us look at some examples of bad, ok, and good boundaries for both the deep and shallow architecture.
#
# ### Shallow Architecture
#
# For the Shallow architecture we will consider $n=4,90,200$.

# %%
include("NN.jl")
# Out:
# NN

# %% [markdown]
# First let us look at $n=4$. Here we have a training error on the order of $\sim$ 0.19

# %%
w = NN.init_weight([(2,10),(10,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w = NN.train(w,dtrn,xtrn,ytrn,1e-4,10000)

class_boundary = NN.boundary(w)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary)
# Out:
# (:epoch, 1000, :trn, 0.21248133150040924)
# (:epoch, 2000, :trn, 0.2117250825498039)
# (:epoch, 3000, :trn, 0.19842544334041742)
# (:epoch, 4000, :trn, 0.19608522934822772)
# (:epoch, 5000, :trn, 0.1949230623646027)
# (:epoch, 6000, :trn, 0.19311544310859963)
# (:epoch, 7000, :trn, 0.19110250606904902)
# (:epoch, 8000, :trn, 0.19034716595849538)
# (:epoch, 9000, :trn, 0.19023078247928418)
# (:epoch, 10000, :trn, 0.1901540377754929)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7202">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip7202)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAHKElEQVR4nO3dQYqcUBhGUQ0uNEvL
# oJdZYKahIWBVq++q5yygy0lz+Qcfb56mZZ0AgKF+jf4AAECQASBBkAEgQJABIECQASBAkAEgQJAB
# IECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEg
# QJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBA
# kAEgYBn9AWz3Wv+c/pvL/Pv03wR4IhcyAAQIMgAECDIABAgyAAQIMgAECDIABMzTtKyjP+LpRsyZ
# +IwZGHAUFzIABAgyAAQIMgAECDIABAgyAAQIMgAEmD0dzKSJKzLvgvO5kAEgQJABIECQASBAkAEg
# QJABIECQASBAkAEgwA75Q/bFcH321pS4kAEgQJABIECQASBAkAEgQJABIECQASDA7OkbcybgqczA
# xnIhA0CAIANAgCADQIAgA0CAIANAgCADQMAy+gPOZNIEPJE50zW4kAEgQJABIECQASBAkAEgQJAB
# IECQASBAkAEg4BY7ZPti4Insi+/FhQwAAYIMAAGCDAABggwAAYIMAAGCDAABt5g9AdyNSdPzuJAB
# IECQASBAkAEgQJABIECQASBAkAEgID178ooTcDfmTPyPCxkAAgQZAAIEGQACBBkAAgQZAAIEGQAC
# hs2eTJqAOzFn4qdcyAAQIMgAECDIABAgyAAQIMgAECDIABAgyAAQsPsO2b4YuBsbY87gQgaAAEEG
# gABBBoAAQQaAAEEGgABBBoCAzbMncyYAOI4LGQACBBkAAgQZAAIEGQACBBkAAgQZAALm1/q1jv4I
# gBG84kSJCxkAAgQZAAIEGQACBBkAAgQZAAIEGQACBBkAAuZpWjbtkD2/CFyFfTFX5EIGgABBBoAA
# QQaAAEEGgABBBoAAQQaAgGX0BwDA3W2ZDruQASBAkAEgQJABIECQASBAkAEgQJABIGB+rV+bXnsC
# KPCSEyV7voToQgaAAEEGgABBBoAAQQaAAEEGgABBBoAArz0BCeZMlOw5Z9rKhQwAAYIMAAGCDAAB
# ggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGeXwQO5VlFakY8rbiF
# CxkAAgQZAAIEGQACBBkAAgQZAAIEGQACzJ6Aj5k0UVKdM23lQgaAAEEGgABBBoAAQQaAAEEGgABB
# BoAAsyd4g5kPnO

# %% [markdown]
# For $n=90$ we have that the training error is of order $\sim$ 0.14

# %%
w90 = NN.init_weight([(2,90),(90,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w90 = NN.train(w90,dtrn,xtrn,ytrn,1e-4,10000)

class_boundary90 = NN.boundary(w90)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary90)
# Out:
# (:epoch, 1000, :trn, 0.42911518780529684)
# (:epoch, 2000, :trn, 0.28045758413168775)
# (:epoch, 3000, :trn, 0.2433027172413472)
# (:epoch, 4000, :trn, 0.22434638128090598)
# (:epoch, 5000, :trn, 0.21177051623718335)
# (:epoch, 6000, :trn, 0.20185739065169125)
# (:epoch, 7000, :trn, 0.19312286162671802)
# (:epoch, 8000, :trn, 0.1861321571172798)
# (:epoch, 9000, :trn, 0.15114193603779152)
# (:epoch, 10000, :trn, 0.14414559239169886)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7400)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7402">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip7402)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAInElEQVR4nO3dXYrjRgBGUTtooVla
# HnqZDcrjZAIeyu2y60o6ZwEz8o/6UuAP3W+3bb8Bh/a9/7P6Eh7a7n9P/feqr3X26+R6/lp9AQCA
# IANAgiADQIAgA0CAIANAgCADQIAgA0DAtvoC4Keqe9RRo7vVo7/O0eu34+XqnJABIECQASBAkAEg
# QJABIECQASBAkAEgwOzphI4+k+GafG+5OidkAAgQZAAIEGQACBBkAAgQZAAIEGQACLjfbtu++iKu
# ztwDrsNTrXjECRkAAgQZAAIEGQACBBkAAgQZAAIEGQACBBkAAjx+MWB0l2ivDHBeTsgAECDIABAg
# yAAQIMgAECDIABAgyAAQIMgAECDIABAgyAAQIMgAECDIABAgyAAQIMgAEHC/3bZ99UUwl6dCwTWM
# PimOY3BCBoAAQQaAAEEGgABBBoAAQQaAAEEGgABBBoAAQQaAAEEGgABBBoAAQQaAAEEGgABBBoAA
# QQaAAI9fvKgzPKJx5NFzZ3id8CqPaTwGJ2QACBBkAAgQZAAIEGQACBBkAAgQZAAIMHvij8qzoZlT
# jvLrhE8xj1rLCRkAAgQZAAIEGQACBBkAAgQZAAIEGQACzJ74oxVzoPL0wjwKxpTv4yonZAAIEGQA
# CBBkAAgQZAAIEGQACBBkAAgQZAAIsENmipn73KPvF0ffi9HXafvM1R39b8IoJ2QACBBkAAgQZAAI
# EGQACBBkAAgQZAAI2FZfAJzN7IlGefJhkgXzOCEDQIAgA0CAIANAgCADQIAgA0CAIANAgKc9Aadj
# jnUu5enfTE7IABAgyAAQIMgAECDIABAgyAAQIMgAEGD2BFyWedR6V5k0jXBCBoAAQQaAAEEGgABB
# BoAAQQaAAEEGgABBBoAAO2Q+Zvbm036RT7FXfp7783lOyAAQIMgAECDIABAgyAAQIMgAECDIABCw
# rb4A+KmZU5TyRGPkdZav/wxG3l/TKF7lhAwAAYIMAAGCDAABggwAAYIMAAGCDAABZk9wWzOhmvl/
# jv5b5lHQ5YQMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAF2yP/jEWq8yneIM7Nlfx8nZAAIEGQA
# CBBkAAgQZAAIEGQACBBkAAi4327bvvoijsi0BUxg/usMfxN8nms5IQNAgCADQIAgA0CAIANAgCAD
# QIAgA0CA2dObnWEKAa8wpfld+W+Cz2otJ2QACBBkAAgQZAAIEGQACBBkAAgQZAAImD57WvGT/qP/
# VL88g4BXHf3+XG

# %% [markdown]
# For $n=200$ we have that the training error is of order $\sim$ 0.06

# %%
w200 = NN.init_weight([(2,200),(200,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w200 = NN.train(w200,dtrn,xtrn,ytrn,1e-4,15000)

class_boundary200 = NN.boundary(w200)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary200)
# Out:
# (:epoch, 1000, :trn, 0.1160934282006071)
# (:epoch, 2000, :trn, 0.0934147476343309)
# (:epoch, 3000, :trn, 0.0745495627198506)
# (:epoch, 4000, :trn, 0.06722216215982206)
# (:epoch, 5000, :trn, 0.0630529991496183)
# (:epoch, 6000, :trn, 0.061023842810720694)
# (:epoch, 7000, :trn, 0.0596613697134431)
# (:epoch, 8000, :trn, 0.059953186126739465)
# (:epoch, 9000, :trn, 0.0600638873722353)
# (:epoch, 10000, :trn, 0.060697901604027195)
# (:epoch, 11000, :trn, 0.0620315601145066)
# (:epoch, 12000, :trn, 0.06094200306163978)
# (:epoch, 13000, :trn, 0.061529368979099316)
# (:epoch, 14000, :trn, 0.06007151466591945)
# (:epoch, 15000, :trn, 0.06149459008682969)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7600)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7602">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip7602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip7600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip7600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip7602)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAIeUlEQVR4nO3d0Y7ixgJFUYj8ofm0
# PMxntkQeWyTqmQIMte1a6znK9W2wt0rixNfLZbtdgKyv2z+zL+Ejtuvfsy8Bpvpr9gUAAIIMAAmC
# DAABggwAAYIMAAGCDAABggwAAVc7ZNjXKrvhWeyVOSsnZAAIEGQACBBkAAgQZAAIEGQACBBkAAjY
# Zl8AwCNGZmWmURyREzIABAgyAAQIMgAECDIABAgyAAQIMgAEmD1xat68xO+Mfj/MqPgEJ2QACBBk
# AAgQZAAIEGQACBBkAAgQZAAIEGQACLheLttt9kXAM2yMKbFV5lVOyAAQIMgAECDIABAgyAAQIMgA
# ECDIABDg9YsnNGMOZPIB8BonZAAIEGQACBBkAAgQZAAIEGQACBBkAAjwtqeAVd5atPc0apW/G+di
# IshPnJABIECQASBAkAEgQJABIECQASBAkAEgwOzpP0xp+J0ZkxXfSX5iQnUuTsgAECDIABAgyAAQ
# IMgAECDIABAgyAAQIMgAELDNvoBPsufkJ+U9p+0zrMEJGQACBBkAAgQZAAIEGQACBBkAAgQZAALS
# r180veB3ylOlVbhHz8U9NZcTMgAECDIABAgyAAQIMgAECDIABAgyAAQs9bYnYF97zmRMqOab8RmY
# Wn1zQgaAAEEGgABBBoAAQQaAAEEGgABBBoAAQQaAADtkdjGyJRzdONolAityQgaAAEEGgABBBoAA
# QQaAAEEGgABBBoCA6+Wy3Ub+Qa9GW5MJEjWeRefiGfPNCRkAAgQZAAIEGQACBBkAAgQZAAIEGQAC
# zJ4WZWoAnmtHscrzygkZAAIEGQACBBkAAgQZAAIEGQACBBkAAjY/+z+OVX76D7AiJ2QACBBkAAgQ
# ZAAIEGQACBBkAAgQZAAIEGQACNhmXwD2xTDL6L3nv9fAJzghA0CAIANAgCADQIAgA0CAIANAgCAD
# QIDZE8AfjMyjTKN4lRMyAAQIMgAECDIABAgyAAQIMgAECDIABJg9wQP2nLZ4y9e57P15mlGtxwkZ
# AAIEGQACBBkAAgQZAAIEGQACBBkAAgQZAALskN/M1vR9jr7TPPr1Xy6+37AnJ2QACBBkAAgQZAAI
# EGQACBBkAAgQZAAIOMXsyfQC5hiZbrk/edXoRPDo3zUnZAAIEGQACBBkAAgQZAAIEGQACBBkAAi4
# Xi7bbeQfPMObaUYc/WfzZat8h7jnnnof99Rzqt9JJ2QACBBkAAgQZAAIEGQACBBkAAgQZAAI2Gb9
# bH7Gz85H/r/u/f

# %% [markdown]
# ## Deep Architecture
#
# Now let us $m$ values which according to our conjecture are comparable to the $n$ values choosen above.
# Hence we will look at $m = 2 (1.5m^2 = 6),\ m = 8 (1.5m^2 = 96),\ m = 12 (1.5m^2 = 216)$

# %% [markdown]
# For $m=2$ we got an error on the order of $0.23$ which is similar as the $n=4$ case. Though here the decision boundary looks really bad. Note 0.25 error corresponds to outputing 0.5 for all inputs

# %%
w2 = NN.init_weight([(2,2),(2,2),(2,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w2 = NN.train(w2,dtrn,xtrn,ytrn,1e-4,10000)

class_boundary2 = NN.boundary(w2)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary2)
# Out:
# (:epoch, 1000, :trn, 0.23446607869943853)
# (:epoch, 2000, :trn, 0.23428392016499214)
# (:epoch, 3000, :trn, 0.23426407448615294)
# (:epoch, 4000, :trn, 0.23424370527830166)
# (:epoch, 5000, :trn, 0.23422941609110012)
# (:epoch, 6000, :trn, 0.23422232587398623)
# (:epoch, 7000, :trn, 0.23406497998436507)
# (:epoch, 8000, :trn, 0.23405547145118816)
# (:epoch, 9000, :trn, 0.23404972882661434)
# (:epoch, 10000, :trn, 0.23404763525763322)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7802">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip7802)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAHkUlEQVR4nO3dMY4bRxRFUY4xC9XS
# HHiZAkahbBmUeljdU7e6zokZdFQXP3jg2+Px/vEAgAm+f/w9+xMy/pr9AQCAIANAgiADQIAgA0CA
# IANAgCADQIAgA0DA++wPAOB+7Is/z4UMAAGCDAABggwAAYIMAAGCDAABggwAAWZPADweD1OlK72/
# ffvjb1zIABAgyAAQIMgAECDIABAgyAAQIMgAEGD2BHBz5kzXOTJnOsqFDAABggwAAYIMAAGCDAAB
# ggwAAYIMAAGCDAABdsgAi7Ivvs6Z++KjXMgAECDIABAgyAAQIMgAECDIABAgyAAQYPYEEGTSdJ0Z
# k6YjXMgAECDIABAgyAAQIMgAECDIABAgyAAQYPYE8IXMma5TnTMd5UIGgABBBoAAQQaAAEEGgABB
# BoAAQQaAALMngD8wVZpr9TnTUS5kAAgQZAAIEGQACBBkAAgQZAAIEGQACBBkAAiwQwa2ZV883y4b
# 4yNcyAAQIMgAECDIABAgyAAQIMgAECDIABBg9gTcjjnTfOZMn+dCBoAAQQaAAEEGgABBBoAAQQaA
# AEEGgACzJ2ApJk1zmTNdx4UMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAF2yECCffF8NsZzuZAB
# IECQASBAkAEgQJABIECQASBAkAEgwOwJeJmp0hrMmdbgQgaAAEEGgABBBoAAQQaAAEEGgABBBoAA
# syfgf8yZ1mDOdC8uZAAIEGQACBBkAAgQZAAIEGQACBBkAAgwe4KNmDOtw6RpPy5kAAgQZAAIEGQA
# CBBkAAgQZAAIEGQACBBkAAiwQ4YbsC9eh30xz7iQASBAkAEgQJABIECQASBAkAEgQJABIMDsCeJM
# mtZgzsQoFzIABAgyAAQIMgAECDIABAgyAAQIMgAEmD3BycyU7sekiVFH3gUXMgAECDIABAgyAAQI
# MgAECDIABAgyAAQIMgAE2CHDJ9gY34t9MaPOfBNcyAAQIMgAECDIABAgyAAQIMgAECDIABBg9gQP
# c6a7MWdi1Iw3wYUMAAGCDAABggwAAYIMAAGCDAABggwAAWZP3Jo50/2YNDGq+i64kAEgQJABIECQ
# ASBAkAEgQJABIECQASDA7IllVacLvMaciVGrvwkuZAAIEGQACBBkAAgQZAAIEGQACBBkAAgQZAAI
# sEPmy6y+EeQ19sWM2uXtcCEDQIAgA0CAIANAgCADQIAgA0CAIANAgNkTp9hllsB/mTQxytvxkwsZ
# AAIEGQACBBkAAg

# %% [markdown]
# For $m=8$ we got an error on the order of $0.11$ which is a little bit better than the $n=90$ case.

# %%
w8 = NN.init_weight([(2,8),(8,8),(8,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w8 = NN.train(w8,dtrn,xtrn,ytrn,1e-4,10000)

class_boundary8 = NN.boundary(w8)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary8)
# Out:
# (:epoch, 1000, :trn, 0.1912829808786146)
# (:epoch, 2000, :trn, 0.16695327036416904)
# (:epoch, 3000, :trn, 0.15554400762704465)
# (:epoch, 4000, :trn, 0.15246445281784646)
# (:epoch, 5000, :trn, 0.14703697425982828)
# (:epoch, 6000, :trn, 0.14498560670131047)
# (:epoch, 7000, :trn, 0.13578518374959442)
# (:epoch, 8000, :trn, 0.13437876053096148)
# (:epoch, 9000, :trn, 0.11362878888801141)
# (:epoch, 10000, :trn, 0.10990802937588451)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8000)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8002">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip8002)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAIP0lEQVR4nO3dUWrjSABFUWvQQntp
# 85FlGjSfMxlIKNuy60o6ZwGNEsu5FPSjlttt3W4AwFR/zX4AAECQASBBkAEgQJABIECQASBAkAEg
# QJABIGCd/QDwf/ft79mP8KN1+TP7EYCTckIGgABBBoAAQQaAAEEGgABBBoAAQQaAALMndjEyVTrD
# ZKg8yRpxhs8AzsoJGQACBBkAAgQZAAIEGQACBBkAAgQZAAKW223dZj8En3f0+Q7XZbrFWTkhA0CA
# IANAgCADQIAgA0CAIANAgCADQIAgA0CAHfKB2A7D8dlR8xMnZAAIEGQACBBkAAgQZAAIEGQACBBk
# AAhYR6c0/qv++5gzAeCEDAABggwAAYIMAAGCDAABggwAAYIMAAHLffu6zG1PM6ZbJk3AM0xNr8cJ
# GQACBBkAAgQZAAIEGQACBBkAAgQZAALW2Q/wSSZIAFQ5IQNAgCADQIAgA0CAIANAgCADQIAgA0CA
# IANAgCADQIAgA0CAIANAgCADQIAgA0CAIANAgCADQMClrl+En6zLn93+Ldd8As9wQgaAAEEGgABB
# BoAAQQaAAEEGgABBBoCA5b59bbMfAt5lzzkTzzEDOxffqfdxQgaAAEEGgABBBoAAQQaAAEEGgABB
# BoAAQQaAANcvsgvbRIDXOCEDQIAgA0CAIANAgCADQIAgA0CAIANAgNnTRZkp8Smj75prGrk6J2QA
# CBBkAAgQZAAIEGQACBBkAAgQZAAIWO7b1zb7Iegyj6LGPOoY/O14nBMyAAQIMgAECDIABAgyAAQI
# MgAECDIABLjtCTiUPec0JlSUOCEDQIAgA0CAIANAgCADQIAgA0CAIANAgCADQMByu62uXwT4hb3y
# 41y/+DgnZAAIEGQACBBkAAgQZAAIEGQACBBkAAgwe4KdzZjImJjMZxr1HO/uv5yQASBAkAEgQJAB
# IECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgQJABIECQASBAkAEgYJ39AHAk1Sv2Rp/L
# VXfQ5YQMAAGCDAABggwAAYIMAAGCDAABggwAAcvttm6zHwJmq86ZZjGPepx36H2u8j46IQNAgCAD
# QIAgA0CAIANAgCADQIAgA0CA2RO72HPyMTpxMDOZ7ypzlD15bx93lffMCRkAAgQZAAIEGQACBBkA
# AgQZAAIEGQAC1tkPQNuMiYZZCHBFTsgAECDIABAgyAAQIMgAECDIABAgyAAQIMgAEOD6RX5lE8yr
# rnJ13t589x539H

# %% [markdown]
# For $m=8$ we got an error on the order of $0.3$ which is a little better than the $n=200$ case.

# %%
w12 = NN.init_weight([(2,12),(12,12),(12,1)])
dtrn,xtrn,ytrn = NN.generate_data(1000,10)
w12 = NN.train(w12,dtrn,xtrn,ytrn,1e-4,10000)

class_boundary12 = NN.boundary(w12)
heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary12)
# Out:
# (:epoch, 1000, :trn, 0.18727503000887089)
# (:epoch, 2000, :trn, 0.16331165527582447)
# (:epoch, 3000, :trn, 0.106040338162874)
# (:epoch, 4000, :trn, 0.05595877277185613)
# (:epoch, 5000, :trn, 0.0455829313287703)
# (:epoch, 6000, :trn, 0.04152682546288222)
# (:epoch, 7000, :trn, 0.03894918724356979)
# (:epoch, 8000, :trn, 0.03697423681990431)
# (:epoch, 9000, :trn, 0.03554188166438504)
# (:epoch, 10000, :trn, 0.03491195897200466)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8200)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8202">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip8202)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAIPElEQVR4nO3dTY7bRhhFUSnQQr00
# D3qZDTBD/wQKqluk6pJ1ztiIlW5JFx/gB95vt8d2AwCm+mf2CwAABBkAEgQZAAIEGQACBBkAAgQZ
# AAIEGQACHrNfAOM+t59Df+5x/3Ho66gY+Xn4Wcy3yu8AXuVCBoAAQQaAAEEGgABBBoAAQQaAAEEG
# gIC7xy+yh/Ls5t32nvms8rM1j2J1LmQACBBkAAgQZAAIEGQACBBkAAgQZAAIMHs6kVXmL/AqEyrO
# yIUMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAF2yAH2xdBm18w7uJABIECQASBAkAEgQJABIECQ
# ASBAkAEgwOzpYCZNwO9MqHjGhQwAAYIMAAGCDAABggwAAYIMAAGCDAABZk/fZM4EzGZCdS0uZAAI
# EGQACBBkAAgQZAAIEGQACBBkAAgwe/qLORNwNaPzqJHvP1Or47iQASBAkAEgQJABIECQASBAkAEg
# QJABIECQASDgMfsFvJONMXAle+6Lmc+FDAABggwAAYIMAAGCDAABggwAAYIMAAGXmD35J/3HmfGo
# Nb9PmMOjFedyIQNAgCADQIAgA0CAIANAgCADQIAgA0DA/XZ7bLNfxDPmL/OdfQYx4z109p/Z3nyO
# v2fkfeT9fS0uZAAIEGQACBBkAAgQZAAIEGQACBBkAAgQZAAImLZDtk2cy5aQs/LdcS2+i35xIQNA
# gCADQIAgA0CAIANAgCADQIAgA0DAY+//oEkCcKTqYwnhVS5kAAgQZAAIEGQACBBkAAgQZAAIEGQA
# CNh99sR8np7C6vb+DIzMqEb/TpMsnnEhA0CAIANAgCADQIAgA0CAIANAgCADQMD9dntsI3/QP9Wf
# z5wJzs936det8t3nQgaAAEEGgABBBoAAQQaAAEEGgABBBoAAQQaAgIdNHMDrfJfyKhcyAAQIMgAE
# CDIABAgyAAQIMgAECDIABDxmvwDWebQYAM+5kAEgQJABIECQASBAkAEgQJABIECQASDA7InTqj5d
# Z3TGVn39e1tl1uf3zqtcyAAQIMgAECDIABAgyAAQIMgAECDIABAgyAAQYId8sFU2mPxiZwp8hwsZ
# AAIEGQACBBkAAgQZAAIEGQACBBkAAsyevsmc6ThmQ9cy+vv0mWJ1LmQACBBkAAgQZAAIEGQACBBk
# AAgQZAAIMHsCeKPReZf533pcyAAQIMgAECDIABAgyAAQIMgAECDIABBg9vQXT5w5jhkHwHMuZAAI
# EGQACBBkAAgQZA

# %% [markdown]
# ## 5 Interactive Code
#
# Now that we have some exmples, here is an widget that lets you play with the various parts of the architecture. $\textbf{Note: Some choices of parameters takes a while (10, 15, even 20 minutes to train). }$
#
# $\textbf{Note: There is some variance, due to random initializtion of how the NN does for any set of parameters}$
#
# Here the first input asked for number of nodes. That is $n$ for shallow case, or $m$ for the deep case.
#
# The second input asked for is the learning rate. (For the data used 1e-4)
#
# The final and third input asked for is the number of epochs (For the data used 10000)

# %%
function input(prompt::String="")::String
    print(prompt)
    return chomp(readline())
end

@manipulate for Type = ["Deep", "Shallow"],
                Nodes = parse(Int,input()), 
                mu = parse(Float64, input()),
                epochs = parse(Int, input())
    if Type == "Deep"
        w = NN.init_weight([(2,Nodes),(Nodes,Nodes),(Nodes,1)])
    else
        w = NN.init_weight([(2,Nodes),(Nodes,1)])
    end
    
    dtrn,xtrn,ytrn = NN.generate_data(1000,10)
    w = NN.train(w,dtrn,xtrn,ytrn,mu,epochs)
    
    class_boundary = NN.boundary(w)
    heatmap(linspace(-10,10,50), linspace(-10,10,50), class_boundary)
end
# Out:
# STDIN> 4
# STDIN> 1e-4
# STDIN> 100
# Interact.Options{:ToggleButtons,Any}(13: "input-7" = Deep Any , "Type", "Deep", "Deep", 0, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("Deep"=>"Deep","Shallow"=>"Shallow"), Dict{Any,Any}(Pair{Any,Any}("Shallow", "Shallow"),Pair{Any,Any}("Deep", "Deep"))), Any[], Any[], true, "horizontal")
# Interact.Textbox{Int64}(15: "input-8" = 4 Int64 , "Nodes", nothing, 4)
# Interact.Textbox{Float64}(17: "input-9" = 0.0001 Float64 , "mu", nothing, 0.0001)
# Interact.Textbox{Int64}(19: "input-10" = 100 Int64 , "epochs", nothing, 100)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip0702)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAHX0lEQVR4nO3dS67TQBRFUQd5oAyN
# xhtmpNDkIwWKRyW1ba/VRuBG0NZtHNVt2/bHBgAs9WX1BwAAggwACYIMAAGCDAABggwAAYIMAAGC
# DAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIM
# AAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAABggwA
# AYIMAAGCDAABggwAAYIMAAGCDAABggwAAYIMAAGCDAAB++oPgM+6P75N+7v229dpfxfAZ7iQASBA
# kAEgQJABIECQASBAkAEgQJABIMDsCbbxCZV5FPAqLmQACBBkAAgQZAAIEGQACBBkAAgQZAAIEGQA
# CLBDJmfms4oAR+FCBoAAQQaAAEEGgABBBoAAQQaAAEEGgIDbtu2P1R/BNVxlzuSJRuAzXMgAECDI
# ABAgyAAQIMgAECDIABAgyAAQYPbEFFeZNM1kHgX8zIUMAAGCDAABggwAAYIMAAGCDAABggwAAYIM
# AAF2yAdi63tN9spwDS5kAAgQZAAIEGQACBBkAAgQZAAIEGQACDB7+o1pEUdkGgXH50IGgABBBoAA
# QQaAAEEGgABBBoAAQQaAgH3VP2xeBAA/uJABIECQASBAkAEgQJABIECQASBAkAEg4HZ/fAy99jT7
# NRmzJ3g/r0JBlwsZAAIEGQACBBkAAgQZAAIEGQACBBkAAgQZAAKGd8izzdxD2jTDXPbK8H4uZAAI
# EGQACBBkAAgQZAAIEGQACBBkAAhYNnuayYQK1jCPgnlcyAAQIMgAECDIABAgyAAQIMgAECDIABCw
# r/6AGWZOlWbPOMyoABjhQgaAAEEGgABBBoAAQQaAAEEGgABBBoAAQQaAgFM8v1g2smu2VebMPNEI
# Y1zIABAgyAAQIMgAECDIABAgyAAQIMgAEGD2dCCj8xEzKo7IPIqrcyEDQIAgA0CAIANAgCADQIAg
# A0CAIANAgNnTRZlQcVTmUZyVCxkAAgQZAAIEGQACBBkAAgQZAAIEGQACzJ74o5kTExMq3sU0iiNy
# IQNAgCADQIAgA0CAIANAgCADQIAgA0CAIANAgB0yU6zYfdo184wdMkfkQgaAAEEGgABBBoAAQQaA
# AEEGgABBBoAAsyemOPrMxITqmo7+u+VcXMgAECDIABAgyAAQIMgAECDIABAgyAAQYPbE21xlYmJC
# dT5X+e2ylgsZAA

# %% [markdown]
# ## Bonus
#
# I have the weight saved from when I computed the error for $n=50$ to $n=80$. Below is a small widget to look through their decision boundaries

# %%
using JLD

wn = load("shallow.jld")["weights3"]
@manipulate for n = 51:1:80
    b = NN.boundary(wn[n-50])
    heatmap(linspace(-10,10,50), linspace(-10,10,50), b)
end
# Out:
# Interact.Options{:SelectionSlider,Any}(7: "input-5" = 65 Any , "n", 65, "65", 15, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("51"=>51,"52"=>52,"53"=>53,"54"=>54,"55"=>55,"56"=>56,"57"=>57,"58"=>58,"59"=>59,"60"=>60…), Dict{Any,Any}(Pair{Any,Any}(54, "54"),Pair{Any,Any}(68, "68"),Pair{Any,Any}(77, "77"),Pair{Any,Any}(69, "69"),Pair{Any,Any}(80, "80"),Pair{Any,Any}(62, "62"),Pair{Any,Any}(75, "75"),Pair{Any,Any}(55, "55"),Pair{Any,Any}(60, "60"),Pair{Any,Any}(66, "66")…)), Any[], Any[], true, "horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 35.8488,375.813 520.315,375.813 520.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6102">
#     <rect x="35" y="11" width="485" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6934,375.813 40.6934,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.388,375.813 159.388,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   278.082,375.813 278.082,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.776,375.813 396.776,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   515.47,375.813 515.47,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,372.173 520.315,372.173
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,282.993 520.315,282.993
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,193.812 520.315,193.812
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,104.632 520.315,104.632
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,15.451 520.315,15.451
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 520.315,375.813
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.6934,375.813 40.6934,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.388,375.813 159.388,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   278.082,375.813 278.082,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.776,375.813 396.776,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   515.47,375.813 515.47,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,372.173 43.1158,372.173
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,282.993 43.1158,282.993
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,193.812 43.1158,193.812
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,104.632 43.1158,104.632
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,15.451 43.1158,15.451
#   "/>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.6934, 389.613)" x="40.6934" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 159.388, 389.613)" x="159.388" y="389.613">-5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 278.082, 389.613)" x="278.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.776, 389.613)" x="396.776" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 515.47, 389.613)" x="515.47" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 376.673)" x="29.8488" y="376.673">-10</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 287.493)" x="29.8488" y="287.493">-5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 198.312)" x="29.8488" y="198.312">0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 109.132)" x="29.8488" y="109.132">5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 19.951)" x="29.8488" y="19.951">10</text>
# </g>
# <g clip-path="url(#clip6102)">
# <image width="484" height="364" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAeQAAAFsCAYAAAAdTcpMAAAIhklEQVR4nO3dUW4bNwBFUanQQru0
# fmSZBtTP1EFtUPaMeTk8ZwWyNJMLAnng/XZ7PG9M9fb8Z/ZH+LbH/e/ZH+F/7fLdHv13Vn9PuLK/
# Zn8AAECQASBBkAEgQJABIECQASBAkAEgQJABIOBuh7yO1Te15W3rjO/2yO+j/GyUf3cocUIGgABB
# BoAAQQaAAEEGgABBBoAAQQaAgMfsD8C40flIeQIDwP9zQgaAAEEGgABBBoAAQQaAAEEGgABBBoAA
# tz3BC46clO1y29PR3B7FVTkhA0CAIANAgCADQIAgA0CAIANAgCADQIAgA0CA6xdhI67whC4nZAAI
# EGQACBBkAAgQZAAIEGQACBBkAAgwe1rI6BTF9XT7Ofo3N4+Cn+eEDAABggwAAYIMAAGCDAABggwA
# AYIMAAFmTxc0MkUxjfqake/NFAj4CidkAAgQZAAIEGQACBBkAAgQZAAIEGQACDB7WsiRN/C4OYoj
# 7DIDO/Jv8E7xESdkAAgQZAAIEGQACBBkAAgQZAAIEGQACBBkAAiwQ+ZT9sqv812sw76YEidkAAgQ
# ZAAIEGQACBBkAAgQZAAIEGQACDB7Ak515LWho65w5SP7cUIGgABBBoAAQQaAAEEGgABBBoAAQQaA
# ALOnhZSnHCOfzW04fMbzwe6ckAEgQJABIECQASBAkAEgQJABIECQASBAkAEgwA6ZHzO6o7ZH5TPl
# PT58hxMyAAQIMgAECDIABAgyAAQIMgAECDIABJg9BZhxvGceBezICRkAAgQZAAIEGQACBBkAAgQZ
# AAIEGQACzJ5Y1sg8yjTqekZ+U1NCVuSEDAABggwAAYIMAAGCDAABggwAAYIMAAH32+3xnP0hdmei
# MZ951J5mvHueNT7ihAwAAYIMAAGCDAABggwAAYIMAAGCDAABggwAAa5fhIONblvtUecb/Q2O3Cvb
# PvMRJ2QACBBkAAgQZAAIEGQACBBkAAgQZAAIcP3iQlzTON/IfMSsZR3eqfc8R3M5IQNAgCADQIAg
# A0CAIANAgCADQIAgA0CA2dMFmXLsx1zla7wrr/OsnccJGQACBBkAAgQZAAIEGQACBBkAAgQZAAIE
# GQAC7JBPtvpVfHaa12JD+p7n+zyetdc5IQNAgCADQIAgA0CAIANAgCADQIAgA0CA2VNAeXoxOl0o
# /w2cZ5dpi+f7t11+8xmckAEgQJABIECQASBAkAEgQJABIECQASDA7OmCTDQo2WUmc4X3bpffqsoJ
# GQACBBkAAgQZAA
